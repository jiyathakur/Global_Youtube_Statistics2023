# %% [markdown]
# # ANALYSIS ON GLOBAL YOUTUBE STATISTICS 2023

# %% [markdown]
# ## ABOUT DATASET
# * rank: Position of the YouTube channel based on the number of subscribers
# * Youtuber: Name of the YouTube channel
# * subscribers: Number of subscribers to the channel
# * video views: Total views across all videos on the channel
# * category: Category or niche of the channel
# * Title: Title of the YouTube channel
# * uploads: Total number of videos uploaded on the channel
# * Country: Country where the YouTube channel originates
# * Abbreviation: Abbreviation of the country
# * channel_type: Type of the YouTube channel (e.g., individual, brand)
# * video_views_rank: Ranking of the channel based on total video views
# * country_rank: Ranking of the channel based on the number of subscribers within its country
# * channel_type_rank: Ranking of the channel based on its type (individual or brand)
# * video_views_for_the_last_30_days: Total video views in the last 30 days
# * lowest_monthly_earnings: Lowest estimated monthly earnings from the channel
# * highest_monthly_earnings: Highest estimated monthly earnings from the channel
# * lowest_yearly_earnings: Lowest estimated yearly earnings from the channel
# * highest_yearly_earnings: Highest estimated yearly earnings from the channel
# * subscribers_for_last_30_days: Number of new subscribers gained in the last 30 days
# * created_year: Year when the YouTube channel was created
# * created_month: Month when the YouTube channel was created
# * created_date: Exact date of the YouTube channel's creation
# * Gross tertiary education enrollment (%): Percentage of the population enrolled in tertiary education in the country
# * Population: Total population of the country
# * Unemployment rate: Unemployment rate in the country
# * Urban_population: Percentage of the population living in urban areas
# * Latitude: Latitude coordinate of the country's location
# * Longitude: Longitude coordinate of the country's location

# %%
#importing the libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline       
#inline function(%) is used to get O/P of graph embedded within jupyter notebook below the code cell.

# %%
#Loading the dataset
#read csv file
df=pd.read_csv('Global YouTube Statistics.csv',encoding='unicode_escape')

# %%
df.shape
# Out:
# (995, 28)

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %% [markdown]
# ## DATA PREPARATION AND CLEANING

# %%
df.head(10)
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
# 5     6                       Music    119000000  0.000000e+00
# 6     7         ýýý Kids Diana Show    112000000  9.324704e+10
# 7     8                   PewDiePie    111000000  2.905804e+10
# 8     9                 Like Nastya    106000000  9.047906e+10
# 9    10               Vlad and Niki     98900000  7.718017e+10
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
# 5               NaN                       Music        0            NaN
# 6    People & Blogs         ýýý Kids Diana Show     1111  United States
# 7            Gaming                   PewDiePie     4716          Japan
# 8    People & Blogs            Like Nastya Vlog      493         Russia
# 9     Entertainment               Vlad and Niki      574  United States
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# 1           US          Games  ...                           NaN
# 2           US  Entertainment  ...                     8000000.0
# 3           US      Education  ...                     1000000.0
# 4           IN  Entertainment  ...                     1000000.0
# 5          NaN          Music  ...                           NaN
# 6           US  Entertainment  ...                           NaN
# 7           JP  Entertainment  ...                           NaN
# 8           RU         People  ...                      100000.0
# 9           US  Entertainment  ...                      600000.0
#
#    created_year  created_month  created_date  \
# 0        2006.0            Mar          13.0
# 1        2006.0            Mar           5.0
# 2        2012.0            Feb          20.0
# 3        2006.0            Sep           1.0
# 4        2006.0            Sep          20.0
# 5        2013.0            Sep          24.0
# 6        2015.0            May          12.0
# 7        2010.0            Apr          29.0
# 8        2016.0            Jan          14.0
# 9        2018.0            Apr          23.0
#
#    Gross tertiary education enrollment (%)    Population  Unemployment rate  \
# 0                                     28.1  1.366418e+09               5.36
# 1                                     88.2  3.282395e+08              14.70
# 2                                     88.2  3.282395e+08              14.70
# 3                                     88.2  3.282395e+08              14.70
# 4                                     28.1  1.366418e+09               5.36
# 5                                      NaN           NaN                NaN
# 6                                     88.2  3.282395e+08              14.70
# 7                                     63.2  1.262266e+08               2.29
# 8                                     81.9  1.443735e+08               4.59
# 9                                     88.2  3.282395e+08              14.70
#
#    Urban_population   Latitude   Longitude
# 0       471031528.0  20.593684   78.962880
# 1       270663028.0  37.090240  -95.712891
# 2       270663028.0  37.090240  -95.712891
# 3       270663028.0  37.090240  -95.712891
# 4       471031528.0  20.593684   78.962880
# 5               NaN        NaN         NaN
# 6       270663028.0  37.090240  -95.712891
# 7       115782416.0  36.204824  138.252924
# 8       107683889.0  61.524010  105.318756
# 9       270663028.0  37.090240  -95.712891
#
# [10 rows x 28 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# 1    Film & Animation               youtubemovies        1   United States
# 2       Entertainment                     MrBeast      741   United States
# 3           Education  Cocomelon - Nursery Rhymes      966   United States
# 4               Shows                   SET India   116536           India
# ..                ...                         ...      ...             ...
# 990            Sports               Natan por Aï¿     1200          Brazil
# 991    People & Blogs    Free Fire India Official     1500           India
# 992               NaN                 HybridPanda     2452  United Kingdom
# 993            Gaming                 RobTopGames       39          Sweden
# 994            Comedy                Make Joke Of       62           India
#
#     Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0             IN          Music  ...                     2000000.0
# 1             US          Games  ...                           NaN
# 2             US  Entertainment  ...                     8000000.0
# 3             US      Education  ...                     1000000.0
# 4             IN  Entertainment  ...                     1000000.0
# ..           ...            ...  ...                           ...
# 990           BR  Entertainment  ...                      700000.0
# 991           IN          Games  ...                      300000.0
# 992           GB          Games  ...                        1000.0
# 993           SE          Games  ...                      100000.0
# 994           IN         Comedy  ...                      100000.0
#
#      created_year  created_month  created_date  \
# 0          2006.0            Mar          13.0
# 1          2006.0            Mar           5.0
# 2          2012.0            Feb          20.0
# 3          2006.0            Sep           1.0
# 4          2006.0            Sep          20.0
# ..            ...            ...           ...
# 990        2017.0            Feb          12.0
# 991        2018.0            Sep          14.0
# 992        2006.0            Sep          11.0
# 993        2012.0            May           9.0
# 994        2017.0            Aug           1.0
#
#      Gross tertiary education enrollment (%)    Population  Unemployment rate  \
# 0                                       28.1  1.366418e+09               5.36
# 1                                       88.2  3.282395e+08              14.70
# 2                                       88.2  3.282395e+08              14.70
# 3                                       88.2  3.282395e+08              14.70
# 4                                       28.1  1.366418e+09               5.36
# ..                                       ...           ...                ...
# 990                                     51.3  2.125594e+08              12.08
# 991                                     28.1  1.366418e+09               5.36
# 992                                     60.0  6.683440e+07               3.85
# 993                                     67.0  1.028545e+07               6.48
# 994                                     28.1  1.366418e+09               5.36
#
#      Urban_population   Latitude  Longitude
# 0         471031528.0  20.593684  78.962880
# 1         270663028.0  37.090240 -95.712891
# 2         270663028.0  37.090240 -95.712891
# 3         270663028.0  37.090240 -95.712891
# 4         471031528.0  20.593684  78.962880
# ..                ...        ...        ...
# 990       183241641.0 -14.235004 -51.925280
# 991       471031528.0  20.593684  78.962880
# 992        55908316.0  55.378051  -3.435973
# 993         9021165.0  60.128161  18.643501
# 994       471031528.0  20.593684  78.962880
#
# [995 rows x 28 columns]>

# %%
#checking duplicates
df.duplicated().sum()
# Out:
# 0

# %%
#checking null values
pd.isnull(df).sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# created_month                                5
# created_date                                 5
# Gross tertiary education enrollment (%)    123
# Population                                 123
# Unemployment rate                          123
# Urban_population                           123
# Latitude                                   123
# Longitude                                  123
# dtype: int64

# %%
#acc. to analysis ques we dont need few of columns so delete them
df.drop(columns=['Abbreviation','Unemployment rate','Urban_population','Gross tertiary education enrollment (%)','Title','Latitude','Longitude','created_date','lowest_monthly_earnings','highest_monthly_earnings','Population'],inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# rank                                  0
# Youtuber                              0
# subscribers                           0
# video views                           0
# category                             46
# uploads                               0
# Country                             122
# channel_type                         30
# video_views_rank                      1
# country_rank                        116
# channel_type_rank                    33
# video_views_for_the_last_30_days     56
# lowest_yearly_earnings                0
# highest_yearly_earnings               0
# subscribers_for_last_30_days        337
# created_year                          5
# created_month                         5
# dtype: int64

# %% [markdown]
# ## HANDLING NULL VALUES

# %%
pd.isnull(df).sum()
# Out:
# rank                                  0
# Youtuber                              0
# subscribers                           0
# video views                           0
# category                             46
# uploads                               0
# Country                             122
# channel_type                         30
# video_views_rank                      1
# country_rank                        116
# channel_type_rank                    33
# video_views_for_the_last_30_days     56
# lowest_yearly_earnings                0
# highest_yearly_earnings               0
# subscribers_for_last_30_days        337
# created_year                          5
# created_month                         5
# dtype: int64

# %%
df2=df.fillna(method='pad')     #filling null values with previous value

# %%
df2
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category  uploads         Country   channel_type  \
# 0               Music    20082           India          Music
# 1    Film & Animation        1   United States          Games
# 2       Entertainment      741   United States  Entertainment
# 3           Education      966   United States      Education
# 4               Shows   116536           India  Entertainment
# ..                ...      ...             ...            ...
# 990            Sports     1200          Brazil  Entertainment
# 991    People & Blogs     1500           India          Games
# 992    People & Blogs     2452  United Kingdom          Games
# 993            Gaming       39          Sweden          Games
# 994            Comedy       62           India         Comedy
#
#      video_views_rank  country_rank  channel_type_rank  \
# 0                 1.0           1.0                1.0
# 1           4055159.0        7670.0             7423.0
# 2                48.0           1.0                1.0
# 3                 2.0           2.0                1.0
# 4                 3.0           2.0                2.0
# ..                ...           ...                ...
# 990             525.0          55.0              172.0
# 991            6141.0         125.0               69.0
# 992          129005.0         867.0             1202.0
# 993           35112.0           4.0               69.0
# 994            4568.0         125.0               44.0
#
#      video_views_for_the_last_30_days  lowest_yearly_earnings  \
# 0                        2.258000e+09              6800000.00
# 1                        1.200000e+01                    0.04
# 2                        1.348000e+09              4000000.00
# 3                        1.975000e+09              5900000.00
# 4                        1.824000e+09              5500000.00
# ..                                ...                     ...
# 990                      5.525130e+08              1700000.00
# 991                      6.473500e+07               194200.00
# 992                      6.703500e+04                  201.00
# 993                      3.871000e+06                11600.00
# 994                      2.400000e+07                72000.00
#
#      highest_yearly_earnings  subscribers_for_last_30_days  created_year  \
# 0               1.084000e+08                     2000000.0        2006.0
# 1               5.800000e-01                     2000000.0        2006.0
# 2               6.470000e+07                     8000000.0        2012.0
# 3               9.480000e+07                     1000000.0        2006.0
# 4               8.750000e+07                     1000000.0        2006.0
# ..                       ...                           ...           ...
# 990             2.650000e+07                      700000.0        2017.0
# 991             3.100000e+06                      300000.0        2018.0
# 992             3.200000e+03                        1000.0        2006.0
# 993             1.858000e+05                      100000.0        2012.0
# 994             1.200000e+06                      100000.0        2017.0
#
#     created_month
# 0             Mar
# 1             Mar
# 2             Feb
# 3             Sep
# 4             Sep
# ..            ...
# 990           Feb
# 991           Sep
# 992           Sep
# 993           May
# 994           Aug
#
# [995 rows x 17 columns]

# %%
pd.isnull(df2).sum()
# Out:
# rank                                0
# Youtuber                            0
# subscribers                         0
# video views                         0
# category                            0
# uploads                             0
# Country                             0
# channel_type                        0
# video_views_rank                    0
# country_rank                        0
# channel_type_rank                   0
# video_views_for_the_last_30_days    0
# lowest_yearly_earnings              0
# highest_yearly_earnings             0
# subscribers_for_last_30_days        0
# created_year                        0
# created_month                       0
# dtype: int64

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS AND VISUALIZATION

# %%
len(df2)
# Out:
# 995

# %%
df2.shape
# Out:
# (995, 17)

# %%
#count of unique 'created_year' column
df2.created_year.nunique()
# Out:
# 19

# %%
len(df2.Country.unique())
# Out:
# 49

# %% [markdown]
# So we can see that this dataset is about only 49 countries out of 195.

# %%
df3=df2.head(10)
df3
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
# 5     6                       Music    119000000  0.000000e+00
# 6     7         ýýý Kids Diana Show    112000000  9.324704e+10
# 7     8                   PewDiePie    111000000  2.905804e+10
# 8     9                 Like Nastya    106000000  9.047906e+10
# 9    10               Vlad and Niki     98900000  7.718017e+10
#
#            category  uploads        Country   channel_type  video_views_rank  \
# 0             Music    20082          India          Music               1.0
# 1  Film & Animation        1  United States          Games         4055159.0
# 2     Entertainment      741  United States  Entertainment              48.0
# 3         Education      966  United States      Education               2.0
# 4             Shows   116536          India  Entertainment               3.0
# 5             Shows        0          India          Music         4057944.0
# 6    People & Blogs     1111  United States  Entertainment               5.0
# 7            Gaming     4716          Japan  Entertainment              44.0
# 8    People & Blogs      493         Russia         People             630.0
# 9     Entertainment      574  United States  Entertainment               8.0
#
#    country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# 0           1.0                1.0                      2.258000e+09
# 1        7670.0             7423.0                      1.200000e+01
# 2           1.0                1.0                      1.348000e+09
# 3           2.0                1.0                      1.975000e+09
# 4           2.0                2.0                      1.824000e+09
# 5           2.0                2.0                      1.824000e+09
# 6           3.0                3.0                      7.316740e+08
# 7           1.0                4.0                      3.918400e+07
# 8           5.0               25.0                      4.894700e+07
# 9           5.0                6.0                      5.805740e+08
#
#    lowest_yearly_earnings  highest_yearly_earnings  \
# 0              6800000.00             1.084000e+08
# 1                    0.04             5.800000e-01
# 2              4000000.00             6.470000e+07
# 3              5900000.00             9.480000e+07
# 4              5500000.00             8.750000e+07
# 5                    0.00             0.000000e+00
# 6              2200000.00             3.510000e+07
# 7               117600.00             1.900000e+06
# 8               146800.00             2.300000e+06
# 9              1700000.00             2.790000e+07
#
#    subscribers_for_last_30_days  created_year created_month
# 0                     2000000.0        2006.0           Mar
# 1                     2000000.0        2006.0           Mar
# 2                     8000000.0        2012.0           Feb
# 3                     1000000.0        2006.0           Sep
# 4                     1000000.0        2006.0           Sep
# 5                     1000000.0        2013.0           Sep
# 6                     1000000.0        2015.0           May
# 7                     1000000.0        2010.0           Apr
# 8                      100000.0        2016.0           Jan
# 9                      600000.0        2018.0           Apr

# %%
df4=df2.tail(10)
df4
# Out:
#      rank                  Youtuber  subscribers   video views  \
# 985   986                      TKOR     12400000  3.392023e+09
# 986   987                 ANNA KOVA     12400000  1.395959e+10
# 987   988             Avril Lavigne     12400000  6.202090e+09
# 988   989                    Caylus     12400000  4.779140e+09
# 989   990                 Migos ATL     12400000  6.993406e+09
# 990   991             Natan por Aï¿     12300000  9.029610e+09
# 991   992  Free Fire India Official     12300000  1.674410e+09
# 992   993                     Panda     12300000  2.214684e+09
# 993   994               RobTopGames     12300000  3.741235e+08
# 994   995              Make Joke Of     12300000  2.129774e+09
#
#            category  uploads         Country   channel_type  video_views_rank  \
# 985       Education        0           India         People         4057944.0
# 986  People & Blogs        1           India           Film         4049634.0
# 987           Music      205   United States          Music             999.0
# 988       Education     1340   United States          Games            1442.0
# 989           Music       99   United States  Entertainment             833.0
# 990          Sports     1200          Brazil  Entertainment             525.0
# 991  People & Blogs     1500           India          Games            6141.0
# 992  People & Blogs     2452  United Kingdom          Games          129005.0
# 993          Gaming       39          Sweden          Games           35112.0
# 994          Comedy       62           India         Comedy            4568.0
#
#      country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# 985         124.0             7741.0                        30968000.0
# 986         124.0             5307.0                               2.0
# 987         176.0              150.0                        50188000.0
# 988         175.0               68.0                       177600000.0
# 989         175.0              171.0                        49412000.0
# 990          55.0              172.0                       552513000.0
# 991         125.0               69.0                        64735000.0
# 992         867.0             1202.0                           67035.0
# 993           4.0               69.0                         3871000.0
# 994         125.0               44.0                        24000000.0
#
#      lowest_yearly_earnings  highest_yearly_earnings  \
# 985                    0.00                      0.0
# 986                    0.01                      0.1
# 987               150600.00                2400000.0
# 988               532800.00                8500000.0
# 989               148200.00                2400000.0
# 990              1700000.00               26500000.0
# 991               194200.00                3100000.0
# 992                  201.00                   3200.0
# 993                11600.00                 185800.0
# 994                72000.00                1200000.0
#
#      subscribers_for_last_30_days  created_year created_month
# 985                      100000.0        2006.0           Aug
# 986                      100000.0        2006.0           Jun
# 987                      100000.0        2005.0           Oct
# 988                      400000.0        2016.0           Apr
# 989                      100000.0        2012.0           Jan
# 990                      700000.0        2017.0           Feb
# 991                      300000.0        2018.0           Sep
# 992                        1000.0        2006.0           Sep
# 993                      100000.0        2012.0           May
# 994                      100000.0        2017.0           Aug

# %%
df2.sort_values('video views',ascending=False)
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# 15     16                    Sony SAB     83000000  1.010000e+11
# 6       7         ýýý Kids Diana Show    112000000  9.324704e+10
# ..    ...                         ...          ...           ...
# 173   174          Popular on YouTube     29300000  0.000000e+00
# 1       2              YouTube Movies    170000000  0.000000e+00
# 102   103                        News     36300000  0.000000e+00
# 360   361           Minecraft - Topic     20900000  0.000000e+00
# 5       6                       Music    119000000  0.000000e+00
#
#              category  uploads        Country   channel_type  \
# 0               Music    20082          India          Music
# 3           Education      966  United States      Education
# 4               Shows   116536          India  Entertainment
# 15              Shows    71270          India  Entertainment
# 6      People & Blogs     1111  United States  Entertainment
# ..                ...      ...            ...            ...
# 173             Music        3  United States      Education
# 1    Film & Animation        1  United States          Games
# 102   News & Politics        0  United States  Entertainment
# 360    People & Blogs        0  United States          Games
# 5               Shows        0          India          Music
#
#      video_views_rank  country_rank  channel_type_rank  \
# 0                 1.0           1.0                1.0
# 3                 2.0           2.0                1.0
# 4                 3.0           2.0                2.0
# 15                4.0           5.0                7.0
# 6                 5.0           3.0                3.0
# ..                ...           ...                ...
# 173         4019724.0          50.0             4847.0
# 1           4055159.0        7670.0             7423.0
# 102         4057944.0          32.0                5.0
# 360         4057944.0         100.0               24.0
# 5           4057944.0           2.0                2.0
#
#      video_views_for_the_last_30_days  lowest_yearly_earnings  \
# 0                        2.258000e+09              6800000.00
# 3                        1.975000e+09              5900000.00
# 4                        1.824000e+09              5500000.00
# 15                       1.657000e+09              5000000.00
# 6                        7.316740e+08              2200000.00
# ..                                ...                     ...
# 173                      1.000000e+00                    0.00
# 1                        1.200000e+01                    0.04
# 102                      2.110300e+07                    0.00
# 360                      3.837000e+08                    0.00
# 5                        1.824000e+09                    0.00
#
#      highest_yearly_earnings  subscribers_for_last_30_days  created_year  \
# 0               1.084000e+08                     2000000.0        2006.0
# 3               9.480000e+07                     1000000.0        2006.0
# 4               8.750000e+07                     1000000.0        2006.0
# 15              7.960000e+07                     1100000.0        2007.0
# 6               3.510000e+07                     1000000.0        2015.0
# ..                       ...                           ...           ...
# 173             5.000000e-02                      100000.0        2017.0
# 1               5.800000e-01                     2000000.0        2006.0
# 102             0.000000e+00                      300000.0        2013.0
# 360             0.000000e+00                      300000.0        2013.0
# 5               0.000000e+00                     1000000.0        2013.0
#
#     created_month
# 0             Mar
# 3             Sep
# 4             Sep
# 15            Aug
# 6             May
# ..            ...
# 173           Aug
# 1             Mar
# 102           Sep
# 360           Dec
# 5             Sep
#
# [995 rows x 17 columns]

# %%
df2.category.unique()
# Out:
# array(['Music', 'Film & Animation', 'Entertainment', 'Education', 'Shows',
#        'People & Blogs', 'Gaming', 'Sports', 'Howto & Style',
#        'News & Politics', 'Comedy', 'Trailers', 'Nonprofits & Activism',
#        'Science & Technology', 'Movies', 'Pets & Animals',
#        'Autos & Vehicles', 'Travel & Events'], dtype=object)

# %%
df2.channel_type.unique()
# Out:
# array(['Music', 'Games', 'Entertainment', 'Education', 'People', 'Sports',
#        'Film', 'News', 'Comedy', 'Howto', 'Nonprofit', 'Autos', 'Tech',
#        'Animals'], dtype=object)

# %% [markdown]
# ### VIDEO VIEWS WRT CATEGORY

# %%
#max video views on youtube channel
plt.figure(figsize=(12,8))
plt.title('video views wrt category')
plt.xticks(rotation=75)
sns.scatterplot(x='category',y='video views',data=df2);

# %% [markdown]
# We can see from scatter plot that Music followed by Education has highest video views in Category while Travel & Events has least video views.

# %% [markdown]
# ### UPLOADS VS SUBSCRIBERS

# %%
len(df2[df2.uploads==0])
# Out:
# 43

# %%
df2[df2.uploads==0]['subscribers']
# Out:
# 5      119000000
# 12      93600000
# 57      44500000
# 73      40600000
# 102     36300000
# 113     34600000
# 149     31400000
# 166     30100000
# 180     28500000
# 190     27800000
# 217     26100000
# 226     25600000
# 236     25200000
# 273     23700000
# 299     22900000
# 340     21400000
# 360     20900000
# 377     20400000
# 386     20200000
# 394     20100000
# 440     18900000
# 463     18400000
# 468     18300000
# 476     18100000
# 508     17600000
# 544     16800000
# 554     16600000
# 592     16100000
# 600     16100000
# 604     16000000
# 606     15900000
# 629     15500000
# 634     15500000
# 680     15000000
# 710     14800000
# 735     14500000
# 762     14400000
# 777     14200000
# 853     13400000
# 877     13200000
# 951     12500000
# 983     12400000
# 985     12400000
# Name: subscribers, dtype: int64

# %% [markdown]
# So,we see that there are 43 channels having zero uploads and not with zero subscribers.

# %%
#checking for first 100 youtubers
plt.figure(figsize=(20,8))
plt.xticks(rotation=75)
sns.barplot(x='subscribers',y='uploads',data=df2.head(100));

# %%
fig,axes=plt.subplots(3,2,figsize=(15,10))
plt.tight_layout(pad=3)
#plt.title('subscribers with uploads')
new=df2[df2.uploads<500]
sns.lineplot(x='uploads',y='subscribers',data=new,ax=axes[0,0]);
#sns.scatterplot(x='uploads',y='subscribers',data=new,ax=axes[0,0]);

new2=df2[df2.uploads<1000]
sns.lineplot(x='uploads',y='subscribers',data=new2,ax=axes[0,1]);

new3=df2[df2.uploads<5000]
sns.lineplot(x='uploads',y='subscribers',data=new3,ax=axes[1,0]);

new4=df2[df2.uploads<10000]
sns.lineplot(x='uploads',y='subscribers',data=new4,ax=axes[1,1]);

new5=df2[df2.uploads<20000]
sns.lineplot(x='uploads',y='subscribers',data=new5,ax=axes[2,0]);

new6=df2[df2.uploads>=20000]
sns.lineplot(x='uploads',y='subscribers',data=new6,ax=axes[2,1]);

# %% [markdown]
# We cannot see any relationship between subscribers and uploads.There are some peaks which describes with increase in uploads subscribers increased for some channels.

# %% [markdown]
# ### % OF CHANNEL TYPE

# %%
var7=df2.channel_type.value_counts()*100/df2.channel_type.count()
sns.barplot(x=var7,y=var7.index,palette='rocket')
plt.title('percentage vs channel type')
plt.xlabel('Percentage');

# %%
fig,axes=plt.subplots(figsize=(15,10))
plt.title('% of channel type')

plt.pie(df2.channel_type.value_counts(),labels=df2.channel_type.value_counts().index,autopct='%1.1f%%',startangle=180);

# %% [markdown]
# We can see from pie chart that 31.3% channels are of Entertainment type followed by 22.6% of Music type channels while Nonprofit has least contribution.

# %% [markdown]
# ### CONTENT ADDED CHANNEL-WISE

# %%
plt.figure(figsize=(15,4))
plt.title('Content Added channel wise')

sns.lineplot(data=df2,x='channel_type',y='uploads');

# %% [markdown]
# As we can see from lineplot that channel type - News has the highest uploads followed by Nonprofit.

# %% [markdown]
# ### NUMBER OF CHANNELS CREATED OVER TIME

# %%
month_year=df2.groupby('created_year')['created_month'].value_counts().unstack()
plt.figure(figsize=(12,6))
plt.title('number of channels created over time')
plt.xticks(rotation=0)
plt.yticks(rotation=75)
sns.heatmap(month_year,linewidths=0.025,annot=True,cmap='vlag');
plt.xlabel('Month')
plt.ylabel('Year');

# %% [markdown]
# As we can see the number of channel created at youtube in march 2006 was highest and equals to 15 followed by july 2014 in which it was 14.

# %% [markdown]
# ### CHANNEL TYPE RANK 1 ANALYSIS

# %%
var7=df2[df2.channel_type_rank==1]
var7[var7.columns[1:8]].style.background_gradient(cmap='flag')
# Out:
# <style type="text/css">
# #T_d025d_row0_col1, #T_d025d_row0_col2, #T_d025d_row5_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_d025d_row0_col4 {
#   background-color: #ffa570;
#   color: #000000;
# }
# #T_d025d_row1_col1 {
#   background-color: #7eb3ff;
#   color: #000000;
# }
# #T_d025d_row1_col2 {
#   background-color: #af0000;
#   color: #f1f1f1;
# }
# #T_d025d_row1_col4, #T_d025d_row2_col4, #T_d025d_row4_col2, #T_d025d_row4_col4, #T_d025d_row6_col4, #T_d025d_row7_col4, #T_d025d_row9_col4, #T_d025d_row10_col4, #T_d025d_row11_col1, #T_d025d_row11_col4 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_d025d_row2_col1 {
#   background-color: #ff693c;
#   color: #f1f1f1;
# }
# #T_d025d_row2_col2 {
#   background-color: #8cc0ff;
#   color: #000000;
# }
# #T_d025d_row3_col1 {
#   background-color: #0000cd;
#   color: #f1f1f1;
# }
# #T_d025d_row3_col2 {
#   background-color: #caecff;
#   color: #000000;
# }
# #T_d025d_row3_col4 {
#   background-color: #930000;
#   color: #f1f1f1;
# }
# #T_d025d_row4_col1 {
#   background-color: #3965ff;
#   color: #f1f1f1;
# }
# #T_d025d_row5_col1 {
#   background-color: #e60000;
#   color: #f1f1f1;
# }
# #T_d025d_row5_col2 {
#   background-color: #00000b;
#   color: #f1f1f1;
# }
# #T_d025d_row6_col1 {
#   background-color: #ff3d1c;
#   color: #f1f1f1;
# }
# #T_d025d_row6_col2 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_d025d_row7_col1 {
#   background-color: #650000;
#   color: #f1f1f1;
# }
# #T_d025d_row7_col2, #T_d025d_row9_col2, #T_d025d_row11_col2 {
#   background-color: #85b9ff;
#   color: #000000;
# }
# #T_d025d_row8_col1 {
#   background-color: #00004d;
#   color: #f1f1f1;
# }
# #T_d025d_row8_col2 {
#   background-color: #0009ff;
#   color: #f1f1f1;
# }
# #T_d025d_row8_col4 {
#   background-color: #ffe6c0;
#   color: #000000;
# }
# #T_d025d_row9_col1 {
#   background-color: #ffe2b9;
#   color: #000000;
# }
# #T_d025d_row10_col1 {
#   background-color: #000088;
#   color: #f1f1f1;
# }
# #T_d025d_row10_col2 {
#   background-color: #93c6ff;
#   color: #000000;
# }
# </style>
# <table id="T_d025d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d025d_level0_col0" class="col_heading level0 col0" >Youtuber</th>
#       <th id="T_d025d_level0_col1" class="col_heading level0 col1" >subscribers</th>
#       <th id="T_d025d_level0_col2" class="col_heading level0 col2" >video views</th>
#       <th id="T_d025d_level0_col3" class="col_heading level0 col3" >category</th>
#       <th id="T_d025d_level0_col4" class="col_heading level0 col4" >uploads</th>
#       <th id="T_d025d_level0_col5" class="col_heading level0 col5" >Country</th>
#       <th id="T_d025d_level0_col6" class="col_heading level0 col6" >channel_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d025d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d025d_row0_col0" class="data row0 col0" >T-Series</td>
#       <td id="T_d025d_row0_col1" class="data row0 col1" >245000000</td>
#       <td id="T_d025d_row0_col2" class="data row0 col2" >228000000000.000000</td>
#       <td id="T_d025d_row0_col3" class="data row0 col3" >Music</td>
#       <td id="T_d025d_row0_col4" class="data row0 col4" >20082</td>
#       <td id="T_d025d_row0_col5" class="data row0 col5" >India</td>
#       <td id="T_d025d_row0_col6" class="data row0 col6" >Music</td>
#     </tr>
#     <tr>
#       <th id="T_d025d_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d025d_row1_col0" class="data row1 col0" >MrBeast</td>
#       <td id="T_d025d_row1_col1" class="data row1 col1" >166000000</td>
#       <td id="T_d025d_row1_col2" class="data row1 col2" >28368841870.000000</td>
#       <td id="T_d025d_row1_col3" class="data row1 col3" >Entertainment</td>
#       <td id="T_d025d_row1_col4" class="data row1 col4" >741</td>
#       <td id="T_d025d_row1_col5" class="data row1 col5" >United States</td>
#       <td id="T_d025d_row1_col6" class="data row1 col6" >Entertainment</td>
#     </tr>
#     <tr>
#       <th id="T_d025d_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d025d_row2_col0" class="data row2 col0" >Cocomelon - Nursery Rhymes</td>
#       <td id="T_d025d_row2_col1" class="data row2 col1" >162000000</td>
#       <td id="T_d025d_row2_col2" class="data row2 col2" >164000000000.000000</td>
#       <td id="T_d025d_row2_col3" class="data row2 col3" >Education</td>
#       <td id="T_d025d_row2_col4" class="data row2 col4" >966</td>
#       <td id="T_d025d_row2_col5" class="data row2 col5" >United States</td>
#       <td id="T_d025d_row2_col6" class="data row2 col6" >Education</td>
#     </tr>
#     <tr>
#       <th id="T_d025d_level0_row3" class="row_heading level0 row3" >11</th>
#       <td id="T_d025d_row3_col0" class="data row3 col0" >WWE</td>
#       <td id="T_d025d_row3_col1" class="data row3 col1" >96000000</td>
#       <td id="T_d025d_row3_col2" class="data row3 col2" >77428473662.000000</td>
#       <td id="T_d025d_row3_col3" class="data row3 col3" >Sports</td>
#       <td id="T_d025d_row3_col4" class="data row3 col4" >70127</td>
#       <td id="T_d025d_row3_col5" class="data row3 col5" >United States</td>
#       <td id="T_d025d_row3_col6" class="data row3 col6" >Sports</td>
#     </tr>
#     <tr>
#       <th id="T_d025d_level0_row4" class="row_heading level0 row4" >12</th>
#       <td id="T_d025d_row4_col0" class="data row4 col0" >Gaming</td>
#       <td id="T_d025d_row4_col1" class="data row4 col1" >93600000</td>
#       <td id="T_d025d_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_d025d_row4_col3" class="data row4 col3" >Sports</td>
#       <td id="T_d025d_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_d025d_row4_col5" class="data row4 col5" >United States</td>
#       <td id="T_d025d_row4_col6" class="data row4 col6" >Games</td>
#     </tr>
#     <tr>
#       <th id="T_d025d_level0_row5" class="row_heading level0 row5" >33</th>
#       <td id="T_d025d_row5_col0" class="data row5 col0" >Aaj Tak</td>
#       <td id="T_d025d_row5_col1" class="data row5 col1" >57600000</td>
#       <td id="T_d025d_row5_col2" class="data row5 col2" >25307753534.000000</td>
#       <td id="T_d025d_row5_col3" class="data row5 col3" >News & Politics</td>
#       <td id="T_d025d_row5_col4" class="data row5 col4" >283775</td>
#       <td id="T_d025d_row5_col5" class="data row5 col5" >India</td>
#       <td id="T_d025d_row5_col6" class="data row5 col6" >News</td>
#     </tr>
#     <tr>
#       <th id="T_d025d_level0_row6" class="row_heading level0 row6" >59</th>
#       <td id="T_d025d_row6_col0" class="data row6 col0" >whinderssonnunes</td>
#       <td id="T_d025d_row6_col1" class="data row6 col1" >44200000</td>
#       <td id="T_d025d_row6_col2" class="data row6 col2" >4274709210.000000</td>
#       <td id="T_d025d_row6_col3" class="data row6 col3" >Comedy</td>
#       <td id="T_d025d_row6_col4" class="data row6 col4" >558</td>
#       <td id="T_d025d_row6_col5" class="data row6 col5" >Brazil</td>
#       <td id="T_d025d_row6_col6" class="data row6 col6" >Comedy</td>
#     </tr>
#     <tr>
#       <th id="T_d025d_level0_row7" class="row_heading level0 row7" >71</th>
#       <td id="T_d025d_row7_col0" class="data row7 col0" >Kimberly Loaiza</td>
#       <td id="T_d025d_row7_col1" class="data row7 col1" >41300000</td>
#       <td id="T_d025d_row7_col2" class="data row7 col2" >5603111948.000000</td>
#       <td id="T_d025d_row7_col3" class="data row7 col3" >People & Blogs</td>
#       <td id="T_d025d_row7_col4" class="data row7 col4" >291</td>
#       <td id="T_d025d_row7_col5" class="data row7 col5" >Mexico</td>
#       <td id="T_d025d_row7_col6" class="data row7 col6" >People</td>
#     </tr>
#     <tr>
#       <th id="T_d025d_level0_row8" class="row_heading level0 row8" >84</th>
#       <td id="T_d025d_row8_col0" class="data row8 col0" >TEDx Talks</td>
#       <td id="T_d025d_row8_col1" class="data row8 col1" >38600000</td>
#       <td id="T_d025d_row8_col2" class="data row8 col2" >7339333120.000000</td>
#       <td id="T_d025d_row8_col3" class="data row8 col3" >Nonprofits & Activism</td>
#       <td id="T_d025d_row8_col4" class="data row8 col4" >200933</td>
#       <td id="T_d025d_row8_col5" class="data row8 col5" >United States</td>
#       <td id="T_d025d_row8_col6" class="data row8 c

# %%
len(var7[var7.columns[1:8]])
# Out:
# 12

# %% [markdown]
# We can see in Music channel type T-Series aces the race, MrBeast in Entertainment type while WWE in Sports type.
# Also six youtubers out of twelve are from United States i.e youtubers which aces in 50% channel types are from United States.
# Three are from India also.

# %% [markdown]
# ### SUBSCRIBERS INCREMENT OF LAST MONTH FOR TOP 10 YOUTUBERS

# %%
plt.figure(figsize=(12,6))
plt.title('subscribers for last month')
plt.xticks(rotation=75)
sns.barplot(x='Youtuber',y='subscribers_for_last_30_days',data=df3,palette='crest');
plt.ylabel('Number of new subscribers gained in the last 30 days');

# %% [markdown]
# As we can see from above barplot that MrBeast has seen increment in their subscribers followed by T-Series and YouTube Movies which both have seen same increment whereas Like Nastya has seen least increment among top 10 youtubers.

# %% [markdown]
# ### LEAST SUBSCRIBED YOUTUBERS ,THEIR COUNTRIES AND SUBSCRIBERS

# %%
df2[df2.columns[1:7]].sort_values('subscribers',ascending=True).head(10).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_dca78_row0_col1, #T_dca78_row1_col1, #T_dca78_row2_col1, #T_dca78_row2_col2, #T_dca78_row2_col4, #T_dca78_row3_col1, #T_dca78_row4_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_dca78_row0_col2 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_dca78_row0_col4 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_dca78_row1_col2, #T_dca78_row3_col4, #T_dca78_row5_col1, #T_dca78_row6_col1, #T_dca78_row7_col1, #T_dca78_row8_col1, #T_dca78_row9_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_dca78_row1_col4 {
#   background-color: #fb7050;
#   color: #f1f1f1;
# }
# #T_dca78_row3_col2 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_dca78_row4_col2, #T_dca78_row7_col4, #T_dca78_row9_col2 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_dca78_row4_col4 {
#   background-color: #f14130;
#   color: #f1f1f1;
# }
# #T_dca78_row5_col2 {
#   background-color: #fa6648;
#   color: #f1f1f1;
# }
# #T_dca78_row5_col4 {
#   background-color: #f75b40;
#   color: #f1f1f1;
# }
# #T_dca78_row6_col2 {
#   background-color: #c7171c;
#   color: #f1f1f1;
# }
# #T_dca78_row6_col4 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_dca78_row7_col2 {
#   background-color: #b11218;
#   color: #f1f1f1;
# }
# #T_dca78_row8_col2 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_dca78_row8_col4 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_dca78_row9_col4 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# </style>
# <table id="T_dca78">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dca78_level0_col0" class="col_heading level0 col0" >Youtuber</th>
#       <th id="T_dca78_level0_col1" class="col_heading level0 col1" >subscribers</th>
#       <th id="T_dca78_level0_col2" class="col_heading level0 col2" >video views</th>
#       <th id="T_dca78_level0_col3" class="col_heading level0 col3" >category</th>
#       <th id="T_dca78_level0_col4" class="col_heading level0 col4" >uploads</th>
#       <th id="T_dca78_level0_col5" class="col_heading level0 col5" >Country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dca78_level0_row0" class="row_heading level0 row0" >994</th>
#       <td id="T_dca78_row0_col0" class="data row0 col0" >Make Joke Of</td>
#       <td id="T_dca78_row0_col1" class="data row0 col1" >12300000</td>
#       <td id="T_dca78_row0_col2" class="data row0 col2" >2129773714.000000</td>
#       <td id="T_dca78_row0_col3" class="data row0 col3" >Comedy</td>
#       <td id="T_dca78_row0_col4" class="data row0 col4" >62</td>
#       <td id="T_dca78_row0_col5" class="data row0 col5" >India</td>
#     </tr>
#     <tr>
#       <th id="T_dca78_level0_row1" class="row_heading level0 row1" >990</th>
#       <td id="T_dca78_row1_col0" class="data row1 col0" >Natan por Aï¿</td>
#       <td id="T_dca78_row1_col1" class="data row1 col1" >12300000</td>
#       <td id="T_dca78_row1_col2" class="data row1 col2" >9029609749.000000</td>
#       <td id="T_dca78_row1_col3" class="data row1 col3" >Sports</td>
#       <td id="T_dca78_row1_col4" class="data row1 col4" >1200</td>
#       <td id="T_dca78_row1_col5" class="data row1 col5" >Brazil</td>
#     </tr>
#     <tr>
#       <th id="T_dca78_level0_row2" class="row_heading level0 row2" >993</th>
#       <td id="T_dca78_row2_col0" class="data row2 col0" >RobTopGames</td>
#       <td id="T_dca78_row2_col1" class="data row2 col1" >12300000</td>
#       <td id="T_dca78_row2_col2" class="data row2 col2" >374123483.000000</td>
#       <td id="T_dca78_row2_col3" class="data row2 col3" >Gaming</td>
#       <td id="T_dca78_row2_col4" class="data row2 col4" >39</td>
#       <td id="T_dca78_row2_col5" class="data row2 col5" >Sweden</td>
#     </tr>
#     <tr>
#       <th id="T_dca78_level0_row3" class="row_heading level0 row3" >992</th>
#       <td id="T_dca78_row3_col0" class="data row3 col0" >Panda</td>
#       <td id="T_dca78_row3_col1" class="data row3 col1" >12300000</td>
#       <td id="T_dca78_row3_col2" class="data row3 col2" >2214684303.000000</td>
#       <td id="T_dca78_row3_col3" class="data row3 col3" >People & Blogs</td>
#       <td id="T_dca78_row3_col4" class="data row3 col4" >2452</td>
#       <td id="T_dca78_row3_col5" class="data row3 col5" >United Kingdom</td>
#     </tr>
#     <tr>
#       <th id="T_dca78_level0_row4" class="row_heading level0 row4" >991</th>
#       <td id="T_dca78_row4_col0" class="data row4 col0" >Free Fire India Official</td>
#       <td id="T_dca78_row4_col1" class="data row4 col1" >12300000</td>
#       <td id="T_dca78_row4_col2" class="data row4 col2" >1674409945.000000</td>
#       <td id="T_dca78_row4_col3" class="data row4 col3" >People & Blogs</td>
#       <td id="T_dca78_row4_col4" class="data row4 col4" >1500</td>
#       <td id="T_dca78_row4_col5" class="data row4 col5" >India</td>
#     </tr>
#     <tr>
#       <th id="T_dca78_level0_row5" class="row_heading level0 row5" >988</th>
#       <td id="T_dca78_row5_col0" class="data row5 col0" >Caylus</td>
#       <td id="T_dca78_row5_col1" class="data row5 col1" >12400000</td>
#       <td id="T_dca78_row5_col2" class="data row5 col2" >4779139505.000000</td>
#       <td id="T_dca78_row5_col3" class="data row5 col3" >Education</td>
#       <td id="T_dca78_row5_col4" class="data row5 col4" >1340</td>
#       <td id="T_dca78_row5_col5" class="data row5 col5" >United States</td>
#     </tr>
#     <tr>
#       <th id="T_dca78_level0_row6" class="row_heading level0 row6" >989</th>
#       <td id="T_dca78_row6_col0" class="data row6 col0" >Migos ATL</td>
#       <td id="T_dca78_row6_col1" class="data row6 col1" >12400000</td>
#       <td id="T_dca78_row6_col2" class="data row6 col2" >6993406259.000000</td>
#       <td id="T_dca78_row6_col3" class="data row6 col3" >Music</td>
#       <td id="T_dca78_row6_col4" class="data row6 col4" >99</td>
#       <td id="T_dca78_row6_col5" class="data row6 col5" >United States</td>
#     </tr>
#     <tr>
#       <th id="T_dca78_level0_row7" class="row_heading level0 row7" >970</th>
#       <td id="T_dca78_row7_col0" class="data row7 col0" >_vector_</td>
#       <td id="T_dca78_row7_col1" class="data row7 col1" >12400000</td>
#       <td id="T_dca78_row7_col2" class="data row7 col2" >7597013023.000000</td>
#       <td id="T_dca78_row7_col3" class="data row7 col3" >Comedy</td>
#       <td id="T_dca78_row7_col4" class="data row7 col4" >398</td>
#       <td id="T_dca78_row7_col5" class="data row7 col5" >United States</td>
#     </tr>
#     <tr>
#       <th id="T_dca78_level0_row8" class="row_heading level0 row8" >971</th>
#       <td id="T_dca78_row8_col0" class="data row8 col0" >DEV Ke Facts</td>
#       <td id="T_dca78_row8_col1" class="data row8 col1" >12400000</td>
#       <td id="T_dca78_row8_col2" class="data row8 col2" >1971226335.000000</td>
#       <td id="T_dca78_row8_col3" class="data row8 col3" >Comedy</td>
#       <td id="T_dca78_row8_col4" class="data row8 col4" >218</td>
#       <td id="T_dca78_row8_col5" class="data row8 col5" >India</td>
#     </tr>
#     <tr>
#       <th id="T_dca78_level0_row9" class="row_heading level0 row9" >972</th>
#       <td id="T_dca78_row9_col0" class="data row9 col0" >Hero Movies 2023</td>
#       <td id="T_dca78_row9_col1" class="data row9 col1" >12400000</td>
#       <td id="T_dca78_row9_col2" class="data row9 col2" >1689090619.000000</td>
#       <td id="T_dca78_row9_col3" class="data row9 col3" >People & Blogs</td>
#       <td id="T_dca78_row9_col4" class="data row9 col4" >689</td>
#       <td id="T_dca78_row9_col5" class="data row9 col5" >India</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### LEAST SUBSCRIBED YOUTUBERS USING BARPLOT

# %%
new=df2[df2.columns[0:4]].sort_values('subscribers',ascending=True).head(9)
plt.figure(figsize=(12,8))
plt.title('Least Subscribed Youtuber')
sns.barplot(x='Youtuber',y='subscribers',data=new,palette='tab20b');

# %% [markdown]
# Make Joke Of,Natan por Aï¿,	RobTopGames,Panda,Free Fire India Official	are the least subscribed youtubers with 12.3M subscribers and are from India,Brazil,Sweden,United Kingdom respectively.

# %% [markdown]
# ### YOUTUBERS AND CATEGORIES HAVING MORE THAN 100M SUBSCRIBERS

# %%
fig,axes=plt.subplots(1,2,figsize=(18,6))
new=df2[df2.subscribers>1e8]
axes[0].set_title('youtubers having more than 100M subscribers')
axes[0].tick_params(axis='x', rotation=65)
sns.barplot(x='Youtuber',y='subscribers',data=new,palette='Set2',ax=axes[0])

g2=sns.barplot(x='category',y='subscribers',data=new,palette='hls',ax=axes[1])
axes[1].set_title('category having more than 100M subscribers')
axes[1].tick_params(axis='x', rotation=65)

# %% [markdown]
# T-Series stands out on top followed by YouTube Movies,MrBeast having more than 100M subscribers while in categories having more than 100M subscribers.Music stands out on top followed by Film & Animation.

# %% [markdown]
# ### INDIA'S TOP 9 YOUTUBERS AND THEIR SUBSCRIBERS,VIDEO VIEWS,CATEGORY,UPLOADS

# %%
new=df2[df2.Country=='India'].head(9)
new[new.columns[1:6]].style.background_gradient(cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_e8b1d_row0_col1, #T_e8b1d_row0_col2, #T_e8b1d_row5_col4 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_e8b1d_row0_col4 {
#   background-color: #ffe997;
#   color: #000000;
# }
# #T_e8b1d_row1_col1 {
#   background-color: #fd8239;
#   color: #f1f1f1;
# }
# #T_e8b1d_row1_col2 {
#   background-color: #f74327;
#   color: #f1f1f1;
# }
# #T_e8b1d_row1_col4 {
#   background-color: #b00026;
#   color: #f1f1f1;
# }
# #T_e8b1d_row2_col1 {
#   background-color: #fec965;
#   color: #000000;
# }
# #T_e8b1d_row2_col2, #T_e8b1d_row2_col4, #T_e8b1d_row8_col1 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_e8b1d_row3_col1 {
#   background-color: #ffe58f;
#   color: #000000;
# }
# #T_e8b1d_row3_col2 {
#   background-color: #fed976;
#   color: #000000;
# }
# #T_e8b1d_row3_col4, #T_e8b1d_row7_col4 {
#   background-color: #fff6b6;
#   color: #000000;
# }
# #T_e8b1d_row4_col1 {
#   background-color: #fff0a8;
#   color: #000000;
# }
# #T_e8b1d_row4_col2 {
#   background-color: #fd9e43;
#   color: #000000;
# }
# #T_e8b1d_row4_col4 {
#   background-color: #fd7234;
#   color: #f1f1f1;
# }
# #T_e8b1d_row5_col1 {
#   background-color: #fffac1;
#   color: #000000;
# }
# #T_e8b1d_row5_col2 {
#   background-color: #fec35e;
#   color: #000000;
# }
# #T_e8b1d_row6_col1, #T_e8b1d_row6_col4, #T_e8b1d_row7_col1 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_e8b1d_row6_col2 {
#   background-color: #fee187;
#   color: #000000;
# }
# #T_e8b1d_row7_col2 {
#   background-color: #ffeda0;
#   color: #000000;
# }
# #T_e8b1d_row8_col2 {
#   background-color: #fed36f;
#   color: #000000;
# }
# #T_e8b1d_row8_col4 {
#   background-color: #bd0026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e8b1d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8b1d_level0_col0" class="col_heading level0 col0" >Youtuber</th>
#       <th id="T_e8b1d_level0_col1" class="col_heading level0 col1" >subscribers</th>
#       <th id="T_e8b1d_level0_col2" class="col_heading level0 col2" >video views</th>
#       <th id="T_e8b1d_level0_col3" class="col_heading level0 col3" >category</th>
#       <th id="T_e8b1d_level0_col4" class="col_heading level0 col4" >uploads</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8b1d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8b1d_row0_col0" class="data row0 col0" >T-Series</td>
#       <td id="T_e8b1d_row0_col1" class="data row0 col1" >245000000</td>
#       <td id="T_e8b1d_row0_col2" class="data row0 col2" >228000000000.000000</td>
#       <td id="T_e8b1d_row0_col3" class="data row0 col3" >Music</td>
#       <td id="T_e8b1d_row0_col4" class="data row0 col4" >20082</td>
#     </tr>
#     <tr>
#       <th id="T_e8b1d_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_e8b1d_row1_col0" class="data row1 col0" >SET India</td>
#       <td id="T_e8b1d_row1_col1" class="data row1 col1" >159000000</td>
#       <td id="T_e8b1d_row1_col2" class="data row1 col2" >148000000000.000000</td>
#       <td id="T_e8b1d_row1_col3" class="data row1 col3" >Shows</td>
#       <td id="T_e8b1d_row1_col4" class="data row1 col4" >116536</td>
#     </tr>
#     <tr>
#       <th id="T_e8b1d_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_e8b1d_row2_col0" class="data row2 col0" >Music</td>
#       <td id="T_e8b1d_row2_col1" class="data row2 col1" >119000000</td>
#       <td id="T_e8b1d_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_e8b1d_row2_col3" class="data row2 col3" >Shows</td>
#       <td id="T_e8b1d_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e8b1d_level0_row3" class="row_heading level0 row3" >10</th>
#       <td id="T_e8b1d_row3_col0" class="data row3 col0" >Zee Music Company</td>
#       <td id="T_e8b1d_row3_col1" class="data row3 col1" >96700000</td>
#       <td id="T_e8b1d_row3_col2" class="data row3 col2" >57856289381.000000</td>
#       <td id="T_e8b1d_row3_col3" class="data row3 col3" >Music</td>
#       <td id="T_e8b1d_row3_col4" class="data row3 col4" >8548</td>
#     </tr>
#     <tr>
#       <th id="T_e8b1d_level0_row4" class="row_heading level0 row4" >15</th>
#       <td id="T_e8b1d_row4_col0" class="data row4 col0" >Sony SAB</td>
#       <td id="T_e8b1d_row4_col1" class="data row4 col1" >83000000</td>
#       <td id="T_e8b1d_row4_col2" class="data row4 col2" >101000000000.000000</td>
#       <td id="T_e8b1d_row4_col3" class="data row4 col3" >Shows</td>
#       <td id="T_e8b1d_row4_col4" class="data row4 col4" >71270</td>
#     </tr>
#     <tr>
#       <th id="T_e8b1d_level0_row5" class="row_heading level0 row5" >21</th>
#       <td id="T_e8b1d_row5_col0" class="data row5 col0" >Zee TV</td>
#       <td id="T_e8b1d_row5_col1" class="data row5 col1" >70500000</td>
#       <td id="T_e8b1d_row5_col2" class="data row5 col2" >73139054467.000000</td>
#       <td id="T_e8b1d_row5_col3" class="data row5 col3" >Entertainment</td>
#       <td id="T_e8b1d_row5_col4" class="data row5 col4" >129204</td>
#     </tr>
#     <tr>
#       <th id="T_e8b1d_level0_row6" class="row_heading level0 row6" >24</th>
#       <td id="T_e8b1d_row6_col0" class="data row6 col0" >ChuChu TV Nursery Rhymes & Kids Songs</td>
#       <td id="T_e8b1d_row6_col1" class="data row6 col1" >65900000</td>
#       <td id="T_e8b1d_row6_col2" class="data row6 col2" >45757850229.000000</td>
#       <td id="T_e8b1d_row6_col3" class="data row6 col3" >Education</td>
#       <td id="T_e8b1d_row6_col4" class="data row6 col4" >633</td>
#     </tr>
#     <tr>
#       <th id="T_e8b1d_level0_row7" class="row_heading level0 row7" >25</th>
#       <td id="T_e8b1d_row7_col0" class="data row7 col0" >Shemaroo Filmi Gaane</td>
#       <td id="T_e8b1d_row7_col1" class="data row7 col1" >65600000</td>
#       <td id="T_e8b1d_row7_col2" class="data row7 col2" >28648024439.000000</td>
#       <td id="T_e8b1d_row7_col3" class="data row7 col3" >Music</td>
#       <td id="T_e8b1d_row7_col4" class="data row7 col4" >8502</td>
#     </tr>
#     <tr>
#       <th id="T_e8b1d_level0_row8" class="row_heading level0 row8" >26</th>
#       <td id="T_e8b1d_row8_col0" class="data row8 col0" >Colors TV</td>
#       <td id="T_e8b1d_row8_col1" class="data row8 col1" >64600000</td>
#       <td id="T_e8b1d_row8_col2" class="data row8 col2" >61510906457.000000</td>
#       <td id="T_e8b1d_row8_col3" class="data row8 col3" >Shows</td>
#       <td id="T_e8b1d_row8_col4" class="data row8 col4" >112915</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### INDIA'S TOP 9 YOUTUBERS USING BARPLOT

# %%
new=df2[df2.Country=='India'].head(9)
plt.figure(figsize=(12,5))
plt.xticks(rotation=75)
sns.barplot(x='Youtuber',y='country_rank',data=new,palette='viridis');

# %% [markdown]
# We can see from above that T-Series is India's rank 1 channel having 245M subscribers with 20082 uploads.

# %% [markdown]
# ### MAXIMUM CONTENT AVAILABLE

# %%
new=df2.sort_values('uploads',ascending=False).head(10)
new[new.columns[1:8]].style.background_gradient(cmap='PuBuGn')
# Out:
# <style type="text/css">
# #T_0a905_row0_col1 {
#   background-color: #5aa2cb;
#   color: #f1f1f1;
# }
# #T_0a905_row0_col2 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_0a905_row0_col4, #T_0a905_row3_col1, #T_0a905_row3_col2 {
#   background-color: #014636;
#   color: #f1f1f1;
# }
# #T_0a905_row1_col1, #T_0a905_row9_col2, #T_0a905_row9_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_0a905_row1_col2 {
#   background-color: #ede3f0;
#   color: #000000;
# }
# #T_0a905_row1_col4 {
#   background-color: #015443;
#   color: #f1f1f1;
# }
# #T_0a905_row2_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_0a905_row2_col2 {
#   background-color: #e3dded;
#   color: #000000;
# }
# #T_0a905_row2_col4 {
#   background-color: #015d4b;
#   color: #f1f1f1;
# }
# #T_0a905_row3_col4 {
#   background-color: #01746c;
#   color: #f1f1f1;
# }
# #T_0a905_row4_col1 {
#   background-color: #66a9cf;
#   color: #f1f1f1;
# }
# #T_0a905_row4_col2 {
#   background-color: #6eabd0;
#   color: #f1f1f1;
# }
# #T_0a905_row4_col4 {
#   background-color: #0e8496;
#   color: #f1f1f1;
# }
# #T_0a905_row5_col1, #T_0a905_row8_col1 {
#   background-color: #faf1f8;
#   color: #000000;
# }
# #T_0a905_row5_col2 {
#   background-color: #d1d1e6;
#   color: #000000;
# }
# #T_0a905_row5_col4 {
#   background-color: #208aa9;
#   color: #f1f1f1;
# }
# #T_0a905_row6_col1 {
#   background-color: #f5ecf5;
#   color: #000000;
# }
# #T_0a905_row6_col2 {
#   background-color: #99b9d9;
#   color: #000000;
# }
# #T_0a905_row6_col4 {
#   background-color: #86b3d5;
#   color: #000000;
# }
# #T_0a905_row7_col1 {
#   background-color: #f1e7f3;
#   color: #000000;
# }
# #T_0a905_row7_col2 {
#   background-color: #f6edf6;
#   color: #000000;
# }
# #T_0a905_row7_col4 {
#   background-color: #efe5f2;
#   color: #000000;
# }
# #T_0a905_row8_col2 {
#   background-color: #e1dcec;
#   color: #000000;
# }
# #T_0a905_row8_col4 {
#   background-color: #f2e9f4;
#   color: #000000;
# }
# #T_0a905_row9_col1 {
#   background-color: #4c9bc7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0a905">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a905_level0_col0" class="col_heading level0 col0" >Youtuber</th>
#       <th id="T_0a905_level0_col1" class="col_heading level0 col1" >subscribers</th>
#       <th id="T_0a905_level0_col2" class="col_heading level0 col2" >video views</th>
#       <th id="T_0a905_level0_col3" class="col_heading level0 col3" >category</th>
#       <th id="T_0a905_level0_col4" class="col_heading level0 col4" >uploads</th>
#       <th id="T_0a905_level0_col5" class="col_heading level0 col5" >Country</th>
#       <th id="T_0a905_level0_col6" class="col_heading level0 col6" >channel_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a905_level0_row0" class="row_heading level0 row0" >95</th>
#       <td id="T_0a905_row0_col0" class="data row0 col0" >ABP NEWS</td>
#       <td id="T_0a905_row0_col1" class="data row0 col1" >37000000</td>
#       <td id="T_0a905_row0_col2" class="data row0 col2" >13102611515.000000</td>
#       <td id="T_0a905_row0_col3" class="data row0 col3" >People & Blogs</td>
#       <td id="T_0a905_row0_col4" class="data row0 col4" >301308</td>
#       <td id="T_0a905_row0_col5" class="data row0 col5" >India</td>
#       <td id="T_0a905_row0_col6" class="data row0 col6" >News</td>
#     </tr>
#     <tr>
#       <th id="T_0a905_level0_row1" class="row_heading level0 row1" >857</th>
#       <td id="T_0a905_row1_col0" class="data row1 col0" >GMA Integrated News</td>
#       <td id="T_0a905_row1_col1" class="data row1 col1" >13400000</td>
#       <td id="T_0a905_row1_col2" class="data row1 col2" >9569814790.000000</td>
#       <td id="T_0a905_row1_col3" class="data row1 col3" >News & Politics</td>
#       <td id="T_0a905_row1_col4" class="data row1 col4" >296272</td>
#       <td id="T_0a905_row1_col5" class="data row1 col5" >Philippines</td>
#       <td id="T_0a905_row1_col6" class="data row1 col6" >News</td>
#     </tr>
#     <tr>
#       <th id="T_0a905_level0_row2" class="row_heading level0 row2" >747</th>
#       <td id="T_0a905_row2_col0" class="data row2 col0" >TV9 Bharatvarsh</td>
#       <td id="T_0a905_row2_col1" class="data row2 col1" >14500000</td>
#       <td id="T_0a905_row2_col2" class="data row2 col2" >10303519926.000000</td>
#       <td id="T_0a905_row2_col3" class="data row2 col3" >People & Blogs</td>
#       <td id="T_0a905_row2_col4" class="data row2 col4" >293516</td>
#       <td id="T_0a905_row2_col5" class="data row2 col5" >India</td>
#       <td id="T_0a905_row2_col6" class="data row2 col6" >News</td>
#     </tr>
#     <tr>
#       <th id="T_0a905_level0_row3" class="row_heading level0 row3" >33</th>
#       <td id="T_0a905_row3_col0" class="data row3 col0" >Aaj Tak</td>
#       <td id="T_0a905_row3_col1" class="data row3 col1" >57600000</td>
#       <td id="T_0a905_row3_col2" class="data row3 col2" >25307753534.000000</td>
#       <td id="T_0a905_row3_col3" class="data row3 col3" >News & Politics</td>
#       <td id="T_0a905_row3_col4" class="data row3 col4" >283775</td>
#       <td id="T_0a905_row3_col5" class="data row3 col5" >India</td>
#       <td id="T_0a905_row3_col6" class="data row3 col6" >News</td>
#     </tr>
#     <tr>
#       <th id="T_0a905_level0_row4" class="row_heading level0 row4" >107</th>
#       <td id="T_0a905_row4_col0" class="data row4 col0" >IndiaTV</td>
#       <td id="T_0a905_row4_col1" class="data row4 col1" >35500000</td>
#       <td id="T_0a905_row4_col2" class="data row4 col2" >16105023749.000000</td>
#       <td id="T_0a905_row4_col3" class="data row4 col3" >News & Politics</td>
#       <td id="T_0a905_row4_col4" class="data row4 col4" >273255</td>
#       <td id="T_0a905_row4_col5" class="data row4 col5" >India</td>
#       <td id="T_0a905_row4_col6" class="data row4 col6" >News</td>
#     </tr>
#     <tr>
#       <th id="T_0a905_level0_row5" class="row_heading level0 row5" >689</th>
#       <td id="T_0a905_row5_col0" class="data row5 col0" >KOMPASTV</td>
#       <td id="T_0a905_row5_col1" class="data row5 col1" >15000000</td>
#       <td id="T_0a905_row5_col2" class="data row5 col2" >11827310821.000000</td>
#       <td id="T_0a905_row5_col3" class="data row5 col3" >News & Politics</td>
#       <td id="T_0a905_row5_col4" class="data row5 col4" >269050</td>
#       <td id="T_0a905_row5_col5" class="data row5 col5" >Indonesia</td>
#       <td id="T_0a905_row5_col6" class="data row5 col6" >News</td>
#     </tr>
#     <tr>
#       <th id="T_0a905_level0_row6" class="row_heading level0 row6" >586</th>
#       <td id="T_0a905_row6_col0" class="data row6 col0" >Thairath Online</td>
#       <td id="T_0a905_row6_col1" class="data row6 col1" >16200000</td>
#       <td id="T_0a905_row6_col2" class="data row6 col2" >14563841315.000000</td>
#       <td id="T_0a905_row6_col3" class="data row6 col3" >News & Politics</td>
#       <td id="T_0a905_row6_col4" class="data row6 col4" >244899</td>
#       <td id="T_0a905_row6_col5" class="data row6 col5" >Thailand</td>
#       <td id="T_0a905_row6_col6" class="data row6 col6" >News</td>
#     </tr>
#     <tr>
#       <th id="T_0a905_level0_row7" class="row_heading level0 row7" >502</th>
#       <td id="T_0a905_row7_col0" class="data row7 col0" >News 24</td>
#       <td id="T_0a905_row7_col1" class="data row7 col1" >17700000</td>
#       <td id="T_0a905_row7_col2" class="data row7 col2" >8396875537.000000</td>
#       <td id="T_0a905_row7_col3" class="data row7 col3" >News & Politics</td>
#       <td id="T_0a905_row7_col4" class="data row7 col4" >211620</td>
#       <td id="T_0a905_row7_col5" class="data row7 col5" >Ukraine</td>
#       <td id="T_0a905_row7_col6" class="data row7 col6" >News</td>
#     </tr>
#     <tr>
#       <th id="T_0a905_level0_row8" class="row_heading level0 row8" >673</th>
#       <td id="T_0a905_row8_col0" class="data row8 col0" >ABS-CBN News</td>
#       <td id="T_0a905_row8_col1" class="data row8 col1" >15100000</td>
#       <td id="T_0a905_row8_col2" class="data row8 col2" >10489367372.000000</td>
#       <td id="T_0a905_row8_col3" class="data row8 col3" >News & Politics</td>
#       <td id="T_0a905_row8_col4" class="data row8 col4" >209520</td>
#       <td id="T_0a905_row8_col5" class="data row8 col5" >Philippines</td>
#       <td id="T_0a905_row8_col6" class="data ro

# %% [markdown]
# ABP NEWS is the 'Youtuber' , 'channel_type' is News and 'category' is People & Blogs.
# Also, we can see that 9 out of 10 have 'channel_type' News.

# %% [markdown]
# ### MAXIMUM CONTENT AVAILABLE COUNTRY-WISE

# %%
new=df2.groupby('Country')['uploads'].value_counts()
plt.figure(figsize=(15,5))
plt.title('countries with most content available')
plt.xticks(rotation=75)
sns.scatterplot(x='Country',y='uploads',data=df2);

# %% [markdown]
# India has the most content available followed by Philippines.Indonesia is on third.

# %% [markdown]
# ### TOP 10 YOUTUBERS WITH MAX. SUBSCRIBERS AND WITH MAX. VIDEO VIEWS GLOBALLY

# %%
fig,axes=plt.subplots(2,1,figsize=(19,15))
plt.tight_layout(pad=6)
axes[0].set_title('Top 10 Youtubers with max subscribers globally')
sns.barplot(y='Youtuber',x='rank',data=df3,palette='tab20b',ax=axes[0]);

new2=df2.sort_values('video views',ascending=False)
new=new2.head(10)
axes[1].set_title('Top 10 Youtubers with max video views globally')
sns.lineplot(y='Youtuber',x='video views',data=new,ax=axes[1]);

# %% [markdown]
# We can see from above plots that T-Series has maximum subscribers as well as maximum video views globally.

# %% [markdown]
# ### EARNING ANALYSIS

# %%
plt.figure(figsize=(9,5))
plt.title('Yearly lowest and highest salary for top 5 Youtubers globally')

plt.plot('Youtuber','lowest_yearly_earnings',data=df2.head(5))
plt.plot('Youtuber','highest_yearly_earnings',data=df2.head(5))

plt.legend(['lowest_yearly_earnings','highest_yearly_earnings'])
plt.ylabel('Earnings');

# %% [markdown]
# We can see from above lineplot that T-Series has highest yearly salary followed by Cocomelon-Nursery Rhymes while YouTube Movies has the lowest yearly salary.

# %% [markdown]
# ## INFERENCES AND CONCLUSIONS

# %% [markdown]
# We've drawn many inferences from the survey. Here's a summary of a few of them:
#
# * Based on the Global Youtube Statistics, we can infer that the data is representative only for the 49 countries out of 195 in the world since youtube is not used in some of countries like China.
#
# * We cannot see any relationship between subscribers and uploads.There are some peaks which describes with increase in uploads subscribers increased for some channels.
#
# * 31.3% channels are of Entertainment type followed by 22.6% of Music type channels while Nonprofit has least contribution.
#
# * United States won in 50% of channel type.
#
# * Number of channel created at youtube in march 2006 was highest and equals to 15 followed by july 2014 in which it was 14.
#
# * T-Series of channel type Music and of Category Music from India stands out on top globally,nationally and has highest subscribers of 245M as well as highest video views with 20082 uploads and  has highest yearly salary.
#
# * Subscribers for last month is increased for MrBeast the highest followed by T-Series and YouTube Movies which both have seen same increment whereas Like Nastya has seen least increment among top 10 youtubers.
#
# * Make Joke Of,Natan por Aï¿,RobTopGames,Panda,Free Fire India Official	are the least subscribed youtubers with 12.3M subscribers and are from India,Brazil,Sweden,United Kingdom respectively.
#
# * Music stands out on top under more than 100M subscribers as well as under highest video views in Category.
#
# * ABP NEWS has the highest uploads under News channel type and People & Blogs Category.
#
# * India has the most content available,highest yearly salary while YouTube Movies from United States has the lowest yearly salary.
